# %% [markdown]
# # EDA with Pandas - Cumulative Lab
#
# ## Introduction
#
# In this section, you've learned a lot about importing, cleaning up, analyzing (using descriptive statistics) and visualizing data. In this cumulative lab, you'll get a chance to practice all of these skills with the Ames Housing dataset, which contains information about home sales in Ames, Iowa between 2006 and 2010.
#
# ## Objectives
#
# You will be able to:
#
# * Practice loading data with pandas
# * Practice calculating measures of centrality and dispersion with pandas
# * Practice creating subsets of data with pandas
# * Practice using data visualizations to explore data, and interpreting those visualizations
# * Perform a full exploratory data analysis process to gain insight about a dataset

# %% [markdown]
# ## Your Task: Explore the Ames Housing Dataset with Pandas
#
# ![aerial photo of a neighborhood](images/neighborhood_aerial.jpg)
#
# Photo by <a href="https://unsplash.com/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Matt Donders</a> on <a href="/@mattdonders?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
#
# Each record (row) in this dataset represents a home that was sold in Ames, IA.
#
# Each feature (column) in this dataset is some attribute of that home sale. You can view the file `data/data_description.txt` in this repository for a full explanation of all variables in this dataset — 80 columns in total.
#
# We are going to focus on the following features:
#
# **SalePrice**: `Sale price of the house in dollars`
#
# **TotRmsAbvGrd**: `Total rooms above grade (does not include bathrooms)`
#
# **OverallCond**: `Rates the overall condition of the house`
# ```
#        10	Very Excellent
#        9	 Excellent
#        8	 Very Good
#        7	 Good
#        6	 Above Average
#        5	 Average
#        4	 Below Average
#        3	 Fair
#        2	 Poor
#        1	 Very Poor
# ```
#
# **YrSold**: `Year Sold (YYYY)`
#
# **YearBuilt**: `Original construction date`
#
# **LandSlope**: `Slope of property`
# ```
#        Gtl	Gentle slope
#        Mod	Moderate Slope
#        Sev	Severe Slope
# ```

# %% [markdown]
# ### Requirements
#
# In this lab you will use your data munging and visualization skills to conduct an exploratory analysis of the dataset.
#
# #### 1. Load the Dataset with Pandas
#
# Import pandas with the standard alias `pd` and load the data into a dataframe with the standard name `df`.
#
# #### 2. Explore Data Distributions
#
# Produce summary statistics, visualizations, and interpretive text describing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# #### 3. Explore Differences between Subsets
#
# Separate the data into subsets based on `OverallCond`, then demonstrate how this split impacts the distribution of `SalePrice`.
#
# #### 4. Explore Correlations
#
# Find the features that have the strongest positive and negative correlations with `SalePrice`, and produce plots representing these relationships.
#
# #### 5. Engineer and Explore a New Feature
#
# Create a new feature `Age`, which represents the difference between the year sold and the year built, and plot the relationship between the age and sale price.

# %% [markdown]
# ## 1. Load the Dataset with Pandas
#
# In the cell below, import:
# * `pandas` with the standard alias `pd`
# * `matplotlib.pyplot` with the standard alias `plt`
#
# And set `%matplotlib inline` so the graphs will display immediately below the cell that creates them.

# %%
# Your code here
import pandas as pd 
import matplotlib.pyplot as plt
# %matploitlib inline
# Out:
# UsageError: Line magic function `%matploitlib` not found.

# %% [markdown]
# Now, use pandas to open the file located at `data/ames.csv` ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)). Specify the argument `index_col=0` in order to avoid creating an extra `Id` column. Name the resulting dataframe `df`.

# %%
# Your code here
File_path = "data/ames.csv"
df = pd.read_csv("data/ames.csv", index_col=0)

# %% [markdown]
# The following code checks that you loaded the data correctly:

# %%
# Run this cell without changes

# Check that df is a dataframe
assert type(df) == pd.DataFrame

# Check that there are the correct number of rows
assert df.shape[0] == 1460

# Check that there are the correct number of columns
# (if this crashes, make sure you specified `index_col=0`)
assert df.shape[1] == 80

# %% [markdown]
# Inspect the contents of the dataframe:

# %%
# Run this cell without changes
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# Run this cell without changes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ## 2. Explore Data Distributions
#
# Write code to produce histograms showing the distributions of `SalePrice`, `TotRmsAbvGrd`, and `OverallCond`.
#
# Each histogram should have appropriate title and axes labels, as well as a black vertical line indicating the mean of the dataset. See the documentation for [plotting histograms](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html), [customizing axes](https://matplotlib.org/stable/api/axes_api.html#axis-labels-title-and-legend), and [plotting vertical lines](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.axvline.html#matplotlib.axes.Axes.axvline) as needed.

# %% [markdown]
# ### Sale Price
#
# In the cell below, produce a histogram for `SalePrice`.

# %%
# Your code here
#Sale price daata and mean 
sale_price_data  = df['SalePrice']
mean_sale_price = sale_price_data.mean()

#create a histogram 
plt.hist(sale_price_data, bins=30, color='lightblue', edgecolor='black')
plt.axvline(mean_sale_price, color='blue',linewidth=2, linestyle='dashed', label='mean')

plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.title('Distribution of Sale Price')
plt.legend()

plt.show()

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here
# Calculate mean, median, and standard deviation of SalePrice
mean_sale_price = df['SalePrice'].mean()
median_sale_price = df['SalePrice'].median()
std_sale_price = df['SalePrice'].std()

print("Mean Sale Price:", mean_sale_price)
print("Median Sale Price:", median_sale_price)
print("Standard Deviation of Sale Price:",std_sale_price)
# Out:
# Mean Sale Price: 180921.19589041095
# Median Sale Price: 163000.0
# Standard Deviation of Sale Price: 79442.50288288663

# %% [markdown]
# In the cell below, interpret the above information.

# %%
# Replace None with appropriate text
"""
The mean price of $180k indicates that the average house in Ames,is sold at this price. 
The median price of $163k suggests that half of the houses were sold for less than this amount and the half sold for more. The fact that the median is less than the mean indicates a right skewed distribution, meaning there are some houses with high values pulling up the average. 
The Standard deviation of $79k indicates a high degree of variability in the house prices. Although the average price is around $180k, houses can seel for about $79k. 
In conclusion, its seems that while houses in Ames, on average sell for $180k there is a significant number of high value houses that increased this mean. The house prices vary as indicated by the high standard deviation. 
"""
# Out:
# '\nThe mean price of $180k indicates that the average house in Ames,is sold at this price. \nThe median price of $163k suggests that half of the houses were sold for less than this amount and the half sold for more. The fact that the median is less than the mean indicates a right skewed distribution, meaning there are some houses with high values pulling up the average. \nThe Standard deviation of $79k indicates a high degree of variability in the house prices. Although the average price is around $180k, houses can seel for about $79k. \nIn conclusion, its seems that while houses in Ames, on average sell for $180k there is a significant number of high value houses that increased this mean. The house prices vary as indicated by the high standard deviation. \n'

# %% [markdown]
# ### Total Rooms Above Grade
#
# In the cell below, produce a histogram for `TotRmsAbvGrd`.

# %%
# TotRmsAbvGrd data and mean
tot_rooms_data = df['TotRmsAbvGrd']
mean_tot_rooms = tot_rooms_data.mean()

#Histogram 
plt.hist(tot_rooms_data, bins=10, color='grey', edgecolor='white')
plt.axvline(mean_tot_rooms, color='black',linewidth=2, linestyle='dashed', label='mean')

#Labels 
plt.xlabel('Total Rooms Above Grade')
plt.ylabel('Frequency')
plt.title('Distribution of Total Rooms Above Grade')
plt.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Your code here
mean_tot_rooms = df['TotRmsAbvGrd'].mean()
median_tot_rooms = df['TotRmsAbvGrd'].median()
std_tot_rooms = df['TotRmsAbvGrd'].std()

# Print the results
print("Mean Total Rooms Above Ground:", mean_tot_rooms)
print("Median Total Rooms Above Ground:", median_tot_rooms)
print("Standard Deviation of Total Rooms Above Ground:", std_tot_rooms)
# Out:
# Mean Total Rooms Above Ground: 6.517808219178082
# Median Total Rooms Above Ground: 6.0
# Standard Deviation of Total Rooms Above Ground: 1.625393290584064

# %% [markdown]
# In the cell below, interpret the above information.

# %%
# Replace None with appropriate text
"""•Mean (6.52): On average, houses in the dataset have approximately 6 to 7 rooms above grade. 
•Median (6.00): Half of the houses in the dataset have 6 or fewer rooms above grade, and the other half have more than 6 rooms. This is close to the mean, suggesting a roughly symmetric distribution around the average number of rooms.
•Standard Deviation (1.63): The standard deviation is a measure of the average amount the number of rooms varies from the mean.
A standard deviation of 1.63 implies that most houses have several rooms above grade within one or two of the mean (i.e., between about 4 to 8 rooms).
"""
# Out:
# '•Mean (6.52): On average, houses in the dataset have approximately 6 to 7 rooms above grade. \n•Median (6.00): Half of the houses in the dataset have 6 or fewer rooms above grade, and the other half have more than 6 rooms. This is close to the mean, suggesting a roughly symmetric distribution around the average number of rooms.\n•Standard Deviation (1.63): The standard deviation is a measure of the average amount the number of rooms varies from the mean.\nA standard deviation of 1.63 implies that most houses have several rooms above grade within one or two of the mean (i.e., between about 4 to 8 rooms).\n'

# %% [markdown]
# ### Overall Condition
#
# In the cell below, produce a histogram for `OverallCond`.

# %%
# OverallCond data and mean
overall_cond_data = df['OverallCond']
mean_overall_cond = overall_cond_data.mean()

# Create a histogram
plt.hist(overall_cond_data, bins=9, color='lightgreen', edgecolor='black')
plt.axvline(mean_overall_cond, color='black', linestyle='dashed', linewidth=2, label='Mean')

# Set labels and title
plt.xlabel('Overall Condition')
plt.ylabel('Frequency')
plt.title('Distribution of Overall Condition')
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Now, print out the mean, median, and standard deviation:

# %%
# Calculate mean, median, and standard deviation of OverallCond
mean_overall_cond = df['OverallCond'].mean()
median_overall_cond = df['OverallCond'].median()
std_overall_cond = df['OverallCond'].std()

# Print the results
print("Mean Overall Condition:", mean_overall_cond)
print("Median Overall Condition:", median_overall_cond)
print("Standard Deviation of Overall Condition:", std_overall_cond)
# Out:
# Mean Overall Condition: 5.575342465753424
# Median Overall Condition: 5.0
# Standard Deviation of Overall Condition: 1.1127993367127367

# %% [markdown]
# In the cell below, interpret the above information.

# %%
# Replace None with appropriate text
"""•Mean (5.58): On average, the overall condition of the houses in the dataset is approximately 5.58 (just above average), based on the given scale from 1 to 10.
•Median (5.00): The median of 5 indicates that 50% of the houses have an overall condition that is average (5) or less, and the other 50% have a condition score greater than 5. This suggests that the condition of houses is mostly around 'average', but there are also quite a few houses with conditions better than 'average'
•Standard Deviation (1.11): The low standard deviation indicates that most of the houses' condition scores are relatively close to the mean (5.58). It tells us that the overall house conditions do not vary widely from the average.
•These figures suggest that the condition of most houses in the dataset is around average or above average, with relatively fewer houses in poor or excellent condition"""
# Out:
# "•Mean (5.58): On average, the overall condition of the houses in the dataset is approximately 5.58 (just above average), based on the given scale from 1 to 10.\n•Median (5.00): The median of 5 indicates that 50% of the houses have an overall condition that is average (5) or less, and the other 50% have a condition score greater than 5. This suggests that the condition of houses is mostly around 'average', but there are also quite a few houses with conditions better than 'average'\n•Standard Deviation (1.11): The low standard deviation indicates that most of the houses' condition scores are relatively close to the mean (5.58). It tells us that the overall house conditions do not vary widely from the average.\n•These figures suggest that the condition of most houses in the dataset is around average or above average, with relatively fewer houses in poor or excellent condition\n"

# %% [markdown]
# ## 3. Explore Differences between Subsets
#
# As you might have noted in the previous step, the overall condition of the house seems like we should treat it as more of a categorical variable, rather than a numeric variable.
#
# One useful way to explore a categorical variable is to create subsets of the full dataset based on that categorical variable, then plot their distributions based on some other variable. Since this dataset is traditionally used for predicting the sale price of a house, let's use `SalePrice` as that other variable.
#
# In the cell below, create three variables, each of which represents a record-wise subset of `df` (meaning, it has the same columns as `df`, but only some of the rows).
#
# * `below_average_condition`: home sales where the overall condition was less than 5
# * `average_condition`: home sales where the overall condition was exactly 5
# * `above_average_condition`: home sales where the overall condition was greater than 5

# %%
# Replace None with appropriate code
below_average_condition = df[df['OverallCond'] < 5]
average_condition = df[df['OverallCond'] == 5]
above_average_condition = df[df['OverallCond'] > 5]

# %% [markdown]
# The following code checks that you created the subsets correctly:

# %%
# Run this cell without changes

# Check that all of them still have 80 columns
assert below_average_condition.shape[1] == 80
assert average_condition.shape[1] == 80
assert above_average_condition.shape[1] == 80

# Check the numbers of rows of each subset
assert below_average_condition.shape[0] == 88
assert average_condition.shape[0] == 821
assert above_average_condition.shape[0] == 551

# %% [markdown]
# The following code will produce a plot of the distributions of sale price for each of these subsets:

# %%
# Run this cell without changes

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Create custom bins so all are on the same scale
bins = range(df["SalePrice"].min(), df["SalePrice"].max(), int(df["SalePrice"].median()) // 20)

# Plot three histograms, with reduced opacity (alpha) so we
# can see them overlapping
ax.hist(
    x=above_average_condition["SalePrice"],
    label="above average condition",
    bins=bins,
    color="cyan",
    alpha=0.5
)
ax.hist(
    x=average_condition["SalePrice"],
    label="average condition",
    bins=bins,
    color="gray",
    alpha=0.3
)
ax.hist(
    x=below_average_condition["SalePrice"],
    label="below average condition",
    bins=bins,
    color="yellow",
    alpha=0.5
)

# Customize labels
ax.set_title("Distributions of Sale Price Grouped by Condition")
ax.set_xlabel("Sale Price")
ax.set_ylabel("Number of Houses")
ax.legend();

# %% [markdown]
# Interpret the plot above. What does it tell us about these overall condition categories, and the relationship between overall condition and sale price? Is there anything surprising?

# %%
# Replace None with appropriate text
"""
The averge and above average condition houses tend to have a higer price than the houses with below average condition as expected. Surprisingly, the average condition houses seem to have a significantly higher selling price than the above average condition houses. This might indicate that there could be other factors driving the higher selling price.
The average condition houses are the hghest in number and also show the highest variability in selling price.
"""
# Out:
# '\nThe averge and above average condition houses tend to have a higer price than the houses with below average condition as expected. Surprisingly, the average condition houses seem to have a significantly higher selling price than the above average condition houses. This might indicate that there could be other factors driving the higher selling price.\nThe average condition houses are the hghest in number and also show the highest variability in selling price.\n'

# %% [markdown]
# ## 4. Explore Correlations
#
# To understand more about what features of these homes lead to higher sale prices, let's look at some correlations. We'll return to using the full `df`, rather than the subsets.
#
# In the cell below, print out both the name of the column and the Pearson correlation for the column that is ***most positively correlated*** with `SalePrice` (other than `SalePrice`, which is perfectly correlated with itself).
#
# We'll only check the correlations with some kind of numeric data type.
#
# You can import additional libraries, although it is possible to do this just using pandas.

# %%
# Select only numeric columns for correlation calculation
numeric_columns = df.select_dtypes(include=[int, float])

# Calculate Pearson correlation for numeric columns with SalePrice
correlations = numeric_columns.corr()['SalePrice'].sort_values(ascending=False)

# Exclude SalePrice correlation with itself (perfect correlation)
correlations = correlations.drop('SalePrice')

# Get the most positively correlated column and its correlation value
most_positively_correlated_column = correlations.index[0]
correlation_value = correlations[0]

print(f"Most Positively Correlated Column: {most_positively_correlated_column}")
print(f"Pearson Correlation: {correlation_value:.2f}")
# Out:
# Most Positively Correlated Column: OverallQual
# Pearson Correlation: 0.79
# /tmp/ipykernel_10220/2960883209.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation_value = correlations[0]

# %% [markdown]
# Now, find the ***most negatively correlated*** column:

# %%
# Calculate Pearson correlation for numeric columns with SalePrice
correlations = numeric_columns.corr()['SalePrice'].sort_values(ascending=True)

# Get the most negatively correlated column and its correlation value
most_negatively_correlated_column = correlations.index[0]
correlation_value = correlations[0]

print(f"Most Negatively Correlated Column: {most_negatively_correlated_column}")
print(f"Pearson Correlation: {correlation_value:.2f}")
# Out:
# Most Negatively Correlated Column: KitchenAbvGr
# Pearson Correlation: -0.14
# /tmp/ipykernel_10220/3404745708.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   correlation_value = correlations[0]

# %% [markdown]
# Once you have your answer, edit the code below so that it produces a box plot of the relevant columns.

# %%
# Replace None with appropriate code

import seaborn as sns

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,5))

# Plot distribution of column with highest correlation
sns.boxplot(
    x=df[most_positively_correlated_column],
    y=df["SalePrice"],
    ax=ax1
)
# Plot distribution of column with most negative correlation
sns.boxplot(
    x=df[most_negatively_correlated_column],
    y=df["SalePrice"],
    ax=ax2
)

# Customize labels
ax1.set_title(f"Box Plot for {most_positively_correlated_column}")
ax1.set_xlabel(f"{most_positively_correlated_column}")
ax1.set_ylabel("Sale Price")
ax2.set_title(f"Box Plot for {most_negatively_correlated_column}")
ax2.set_xlabel(f"{most_negatively_correlated_column}")
ax2.set_ylabel("Sale Price")
# Out:
# /home/eragon/anaconda3/envs/ubuntu_environment/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/eragon/anaconda3/envs/ubuntu_environment/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/eragon/anaconda3/envs/ubuntu_environment/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# Interpret the results below. Consult `data/data_description.txt` as needed.

# %%
# Replace None with appropriate text
"""
There is a positive correlation between the overall quality and the selling price of the houses. The most expensive houses had the highest selling price, with the median selling price for rating 10 being around 450,000 as compared to rating 3, which was about 10,000. We can also note that the houses with the highest overall quality have the highest distribution of selling prices and the distribution reduces as the overall quality goes down.
Most houses had one kitchen, with their selling prices having the highest distribution from below 100,000 upto 700,000. There also seem to be a negative correlation between the number of Kitchen abive grade and selling price because as the number of kitchens above grade increases, the selling price of the houses drops.
"""
# Out:
# '\nThere is a positive correlation between the overall quality and the selling price of the houses. The most expensive houses had the highest selling price, with the median selling price for rating 10 being around 450,000 as compared to rating 3, which was about 10,000. We can also note that the houses with the highest overall quality have the highest distribution of selling prices and the distribution reduces as the overall quality goes down.\nMost houses had one kitchen, with their selling prices having the highest distribution from below 100,000 upto 700,000. There also seem to be a negative correlation between the number of Kitchen abive grade and selling price because as the number of kitchens above grade increases, the selling price of the houses drops.\n'

# %% [markdown]
# ## 5. Engineer and Explore a New Feature
#
# Here the code is written for you, all you need to do is interpret it.
#
# We note that the data spans across several years of sales:

# %%
# Run this cell without changes
df["YrSold"].value_counts().sort_index()
# Out:
# YrSold
# 2006    314
# 2007    329
# 2008    304
# 2009    338
# 2010    175
# Name: count, dtype: int64

# %% [markdown]
# Maybe we can learn something interesting from the age of the home when it was sold. This uses information from the `YrBuilt` and `YrSold` columns, but represents a truly distinct feature.

# %%
# Run this cell without changes

# Make a new column, Age
df["Age"] = df["YrSold"] - df["YearBuilt"]

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Plot Age vs. SalePrice
ax.scatter(df["Age"], df["SalePrice"], alpha=0.3, color="green")
ax.set_title("Home Age vs. Sale Price")
ax.set_xlabel("Age of Home at Time of Sale")
ax.set_ylabel("Sale Price");

# %% [markdown]
# Interpret this plot below:

# %%
# Replace None with appropriate text
"""
The newer houses have the highest selling prices, with prices dropping as the age of the houses increases, indicating a negative correlation between house age and selling prices. Most of the houses are also relatively new, with an age of between 0 and 60 years. We also observed that there are very few houses aged around 20 years.
"""
# Out:
# '\nThe newer houses have the highest selling prices, with prices dropping as the age of the houses increases, indicating a negative correlation between house age and selling prices. Most of the houses are also relatively new, with an age of between 0 and 60 years. We also observed that there are very few houses aged around 20 years.\n'

# %% [markdown]
# ## Summary
#
# Congratulations, you've completed an exploratory data analysis of a popular dataset. You saw how to inspect the distributions of individual columns, subsets of columns, correlations, and new engineered features.
